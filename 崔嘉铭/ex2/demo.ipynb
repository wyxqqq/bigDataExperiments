# %%
import numpy as np
import pandas as pd
import matplotlib

data = pd.read_csv("C:\\Users\\Lenovo\\Desktop\\大三上\\大数据分析实践\\实验\\实验2\\Pokemon.csv", encoding='Windows-1252')
data
# Out:
#              #                   Name     Type 1     Type 2      Total  \
# 0            1              Bulbasaur      Grass     Poison        318
# 1            2                Ivysaur      Grass     Poison        405
# 2            3               Venusaur      Grass     Poison        525
# 3            3  VenusaurMega Venusaur      Grass     Poison        625
# 4            4             Charmander       Fire        NaN        309
# ..         ...                    ...        ...        ...        ...
# 805        721              Volcanion       Fire      Water        600
# 806  undefined              undefined  undefined  undefined  undefined
# 807  undefined              undefined  undefined  undefined  undefined
# 808        NaN                    NaN        NaN        NaN        NaN
# 809        NaN                    NaN        NaN        NaN        NaN
#
#             HP     Attack    Defense    Sp. Atk    Sp. Def      Speed  \
# ...

# %%
data.drop([806, 807, 808, 809], axis=0, inplace=True)
data
# Out:
#        #                   Name   Type 1  Type 2 Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45     49      49
# 1      2                Ivysaur    Grass  Poison   405  60     62      63
# 2      3               Venusaur    Grass  Poison   525  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80    100     123
# 4      4             Charmander     Fire     NaN   309  39     52      43
# ..   ...                    ...      ...     ...   ...  ..    ...     ...
# 801  719                Diancie     Rock   Fairy   600  50    100     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50    160     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80    110      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80    160      60
# 805  721              Volcanion     Fire   Water   600  80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# ...

# %%
type2 = data['Type 2'].value_counts(dropna=True)
type2.plot(kind='bar')
# Out:
# <Axes: xlabel='Type 2'>

# %%
data.drop(data[(data['Type 2']=='273') | (data['Type 2']=='0') | (data['Type 2']=='A') | (data['Type 2']=='BBB')].index, inplace=True, axis=0)
data
# Out:
#        #                   Name   Type 1  Type 2 Total  HP Attack Defense  \
# 0      1              Bulbasaur    Grass  Poison   318  45     49      49
# 1      2                Ivysaur    Grass  Poison   405  60     62      63
# 2      3               Venusaur    Grass  Poison   525  80     82      83
# 3      3  VenusaurMega Venusaur    Grass  Poison   625  80    100     123
# 4      4             Charmander     Fire     NaN   309  39     52      43
# ..   ...                    ...      ...     ...   ...  ..    ...     ...
# 801  719                Diancie     Rock   Fairy   600  50    100     150
# 802  719    DiancieMega Diancie     Rock   Fairy   700  50    160     110
# 803  720    HoopaHoopa Confined  Psychic   Ghost   600  80    110      60
# 804  720     HoopaHoopa Unbound  Psychic    Dark   680  80    160      60
# 805  721              Volcanion     Fire   Water   600  80    110     120
#
#     Sp. Atk Sp. Def Speed Generation Legendary
# ...

# %%
data['#'] = pd.to_numeric(data['#'], errors='coerce')
data['Attack'] = pd.to_numeric(data['Attack'], errors='coerce')
data[['#', 'Attack']].plot(kind='scatter', x='#', y='Attack')
# Out:
# <Axes: xlabel='#', ylabel='Attack'>

# %%
data.drop(data[data['Attack']>800].index, axis=0, inplace=True)
data
# Out:
#          #                   Name   Type 1  Type 2 Total  HP  Attack Defense  \
# 0      1.0              Bulbasaur    Grass  Poison   318  45    49.0      49
# 1      2.0                Ivysaur    Grass  Poison   405  60    62.0      63
# 2      3.0               Venusaur    Grass  Poison   525  80    82.0      83
# 3      3.0  VenusaurMega Venusaur    Grass  Poison   625  80   100.0     123
# 4      4.0             Charmander     Fire     NaN   309  39    52.0      43
# ..     ...                    ...      ...     ...   ...  ..     ...     ...
# 801  719.0                Diancie     Rock   Fairy   600  50   100.0     150
# 802  719.0    DiancieMega Diancie     Rock   Fairy   700  50   160.0     110
# 803  720.0    HoopaHoopa Confined  Psychic   Ghost   600  80   110.0      60
# 804  720.0     HoopaHoopa Unbound  Psychic    Dark   680  80   160.0      60
# 805  721.0              Volcanion     Fire   Water   600  80   110.0     120
#
# ...

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#          #                   Name   Type 1  Type 2 Total  HP  Attack Defense  \
# 0      1.0              Bulbasaur    Grass  Poison   318  45    49.0      49
# 1      2.0                Ivysaur    Grass  Poison   405  60    62.0      63
# 2      3.0               Venusaur    Grass  Poison   525  80    82.0      83
# 3      3.0  VenusaurMega Venusaur    Grass  Poison   625  80   100.0     123
# 4      4.0             Charmander     Fire     NaN   309  39    52.0      43
# ..     ...                    ...      ...     ...   ...  ..     ...     ...
# 801  719.0                Diancie     Rock   Fairy   600  50   100.0     150
# 802  719.0    DiancieMega Diancie     Rock   Fairy   700  50   160.0     110
# 803  720.0    HoopaHoopa Confined  Psychic   Ghost   600  80   110.0      60
# 804  720.0     HoopaHoopa Unbound  Psychic    Dark   680  80   160.0      60
# 805  721.0              Volcanion     Fire   Water   600  80   110.0     120
#
# ...

# %%
data[~(data['Generation'].isin(['1', '2', '3', '4', '5', '6']))]
# Out:
#          #       Name    Type 1  Type 2 Total   HP  Attack Defense Sp. Atk  \
# 11     9.0  Blastoise     Water     NaN   530   79    83.0     100      85
# 32    25.0    Pikachu  Electric     NaN   320   35    55.0      40      50
# 408    NaN        NaN       NaN     NaN   NaN  NaN     NaN     NaN     NaN
# 771  695.0  Heliolisk  Electric  Normal   481   62    55.0      52     109
#
#     Sp. Def Speed Generation Legendary
# 11      105    78      FALSE         1
# 32       50    90      FALSE         0
# 408     NaN   NaN        NaN       NaN
# 771      94   109  undefined     FALSE
