# %%
import pandas as pd
from pandas import DataFrame
import numpy as np

primitive_data=pd.read_csv("data.csv",encoding="gbk")
primitive_data
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
primitive_data_1=primitive_data.dropna(how='any')
primitive_data_1
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1113      1129        546        上海       网络核心    2050      502     石家庄
# 1114      1129        514        上海       网络核心    2473      946      吉林
# 1115     36036        499        长春       一般节点    1257      178      上海
# 1116     36422        346        天津       网络核心    1997       41      天津
# 1117      2701        619        大连       网络核心    2549     1070      沈阳
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1113     网络核心  48731433404  1.000000e+11
# 1114     一般节点  50060666120  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
# 1116     网络核心  50628787089  1.000000e+11
# 1117     网络核心  48753971761  1.000000e+11
#
# [1118 rows x 10 columns]

# %%
data_before_filter=primitive_data_1
data_after_filter_1=data_before_filter.loc[data_before_filter["traffic"]!=0]
data_after_filter_2=data_after_filter_1.loc[data_after_filter_1["from_level"]=='一般节点']
data_after_filter_2
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 1104        63          6        通辽       一般节点   36036       20      长春
# 1107     36036         52        长春       一般节点    1129      171      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1097     一般节点  48409925693  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
# 1107     网络核心  49345226162  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
#
# [550 rows x 10 columns]

# %%
data_before_sample=data_after_filter_2
columns=data_before_sample.columns
weight_sample=data_before_sample.copy()
weight_sample['weight']=0
for i in weight_sample.index:
    if weight_sample.at[i,'to_level']=='一般节点':
        weight=1
    else:
        weight=5
    weight_sample.at[i,'weight']=weight

weight_sample_finish=weight_sample.sample(n=50,weights='weight')
#data_before_sample=data_before_sample[columns]
weight_sample_finish=weight_sample[columns]
weight_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 0           47         71        通辽       一般节点    1756      585      北京
# 1           47         74        通辽       一般节点    1756      776      北京
# 2           47        240        通辽       一般节点    1756      802      北京
# 3           47        241        通辽       一般节点    1997      464      天津
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# ...        ...        ...       ...        ...     ...      ...     ...
# 1097      2473       1460        吉林       一般节点     591      586      绥化
# 1103     36036         18        长春       一般节点    3443      650      青岛
# 1104        63          6        通辽       一般节点   36036       20      长春
# 1107     36036         52        长春       一般节点    1129      171      上海
# 1115     36036        499        长春       一般节点    1257      178      上海
#
#      to_level      traffic     bandwidth
# 0        网络核心  49636052613  1.000000e+11
# 1        网络核心  50056871412  1.000000e+11
# 2        网络核心  49453581081  1.000000e+11
# 3        网络核心  49733361585  1.000000e+11
# 4        一般节点  50492573662  1.000000e+11
# ...       ...          ...           ...
# 1097     一般节点  48409925693  1.000000e+11
# 1103     网络核心  48663350759  1.000000e+11
# 1104     一般节点  50355678076  1.000000e+11
# 1107     网络核心  49345226162  1.000000e+11
# 1115     网络核心  50545082113  1.000000e+11
#
# [550 rows x 10 columns]

# %%
random_sample=data_before_sample
random_sample_finish=random_sample.sample(n=50)
random_sample_finish=random_sample_finish[columns]
random_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 583       2473        946        吉林       一般节点   36539     1146      杭州
# 347        180         42      呼和浩特       一般节点    4360      406      南京
# 377        474        467       哈尔滨       一般节点    5058       70      南宁
# 555         63        278        通辽       一般节点   36036       18      长春
# 96         474        360       哈尔滨       一般节点    2473      946      吉林
# 295         63         54        通辽       一般节点    3227      493      济南
# 486         47         74        通辽       一般节点    1385      133      广州
# 23          63         62        通辽       一般节点   36422      394      天津
# 275         47         71        通辽       一般节点    3443     1022      青岛
# 310         96        102      呼和浩特       一般节点     474      678     哈尔滨
# 1035     36036         54        长春       一般节点     591       23      绥化
# 993      36036         18        长春       一般节点    2194      450      唐山
# 562         96        111      呼和浩特       一般节点    3443      101      青岛
# 119        474       1246       哈尔滨       一般节点    3227      705      济南
# 291         47        427        通辽       一般节点    3227      766      济南
# 791        180        264      呼和浩特       一般节点     180      276    呼和浩特
# 57          96        379      呼和浩特       一般节点    1756     1187      北京
# 345        180         36      呼和浩特       一般节点    2841      519      郑州
# 93         180        276      呼和浩特       一般节点   36272      235      太原
# 423        591        558        绥化       一般节点     180       20    呼和浩特
# 67         180         28      呼和浩特       一般节点    1385      133      广州
# 370        474        359       哈尔滨       一般节点    1756      594      北京
# 168        787         52        玉溪       一般节点    3213      246      重庆
# 331         96        346      呼和浩特       一般节点    1756     1128      北京
# 534         47        258        通辽       一般节点    1997       84      天津
# 64         180         18      呼和浩特       一般节点    1536       26    鄂尔多斯
# 775         96        134      呼和浩特       一般节点     180       98    呼和浩特
# 830      36036         54        长春       一般节点     591       11      绥化
# 314         96        114      呼和浩特       一般节点    4561     1086      成都
# 276         47         74        通辽       一般节点    4561     1033      成都
# 587         96        141      呼和浩特       一般节点    3213      246      重庆
# 81         180        202      呼和浩特       一般节点   36272      247      太原
# 85         180        218      呼和浩特       一般节点    3443      650      青岛
# 845         47        243        通辽       一般节点     591      526      绥化
# 536         47        260        通辽       一般节点    1997      468      天津
# 593       2473        803        吉林       一般节点    3227      705      济南
# 61          96        407      呼和浩特       一般节点    4069     1196      宁波
# 743       4069       1195        宁波       一般节点      96      134    呼和浩特
# 427        591        638        绥化       一般节点     235     1649      北京
# 75         180         84      呼和浩特       一般节点    1536       86    鄂尔多斯
# 760       5058         70        南宁       一般节点      96      460    呼和浩特
# 91         180        264      呼和浩特       一般节点      63       70      通辽
# 79         180        192      呼和浩特       一般节点     591      586      绥化
# 112        474        677       哈尔滨       一般节点    3227      195      济南
# 435        591       1258        绥化       一般节点    2473      769      吉林
# 25          63         70        通辽       一般节点     180      264    呼和浩特
# 71         180         38      呼和浩特       一般节点    1385     2778      广州
# 368        180        276      呼和浩特       一般节点    1997      462      天津
# 381        474        475       哈尔滨       一般节点    2473      941      吉林
# 10          47        258        通辽       一般节点    1997      122      天津
#
#      to_level      traffic     bandwidth
# 583      一般节点  50631070410  1.000000e+11
# 347      一般节点  50178810628  1.000000e+11
# 377      一般节点  51745421052  1.000000e+11
# 555      一般节点  50478302302  1.000000e+11
# 96       一般节点  51819320173  1.000000e+11
# 295      网络核心  49566827928  1.000000e+11
# 486      网络核心  49136084036  1.000000e+11
# 23       网络核心  50322780029  1.000000e+11
# 275      网络核心  50975030653  1.000000e+11
# 310      一般节点  49006847943  1.000000e+11
# 1035     一般节点  50638071722  1.000000e+11
# 993      网络核心  49826827167  1.000000e+11
# 562      网络核心  51065224623  1.000000e+11
# 119      网络核心  50954049859  1.000000e+11
# 291      网络核心  49389391674  1.000000e+11
# 791      一般节点  49965760241  1.000000e+11
# 57       网络核心  49400869697  1.000000e+11
# 345      网络核心  49615778204  1.000000e+11
# 93       网络核心  51775514286  1.000000e+11
# 423      一般节点  48364223310  1.000000e+11
# 67       网络核心  52798223188  1.000000e+11
# 370      网络核心  49659526739  1.000000e+11
# 168      网络核心  50468642387  1.000000e+11
# 331      网络核心  49834736741  1.000000e+11
# 534      网络核心  50060087433  1.000000e+11
# 64       网络核心  51722488070  1.000000e+11
# 775      一般节点  51993612239  1.000000e+11
# 830      一般节点  49794381448  1.000000e+11
# 314      网络核心  49729944227  1.000000e+11
# 276      网络核心  50819524115  1.000000e+11
# 587      网络核心  47941844052  1.000000e+11
# 81       网络核心  49867223584  1.000000e+11
# 85       网络核心  50106572586  1.000000e+11
# 845      一般节点  48628217146  1.000000e+11
# 536      网络核心  49794570873  1.000000e+11
# 593      网络核心  49383348895  1.000000e+11
# 61       一般节点  49745162804  1.000000e+11
# 743      一般节点  50099141709  1.000000e+11
# 427      网络核心  50512261162  1.000000e+11
# 75       网络核心  49100967003  1.000000e+11
# 760      一般节点  49703011825  1.000000e+11
# 91       一般节点  50106121660  1.000000e+11
# 79       一般节点  49504348509  1.000000e+11
# 112      网络核心  51631856877  1.000000e+11
# 435      一般节点  49855631239  1.000000e+11
# 25       一般节点  49630519508  1.000000e+11
# 71       网络核心  51626689601  1.000000e+11
# 368      网络核心  51651922009  1.000000e+11
# 381      一般节点  49402590822  1.000000e+11
# 10       网络核心  49594312223  1.000000e+11

# %%
ybjd=data_before_sample.loc[data_before_sample['to_level']=='一般节点']
wlhx=data_before_sample.loc[data_before_sample['to_level']=='网络核心']
after_sample=pd.concat([ybjd.sample(17),wlhx.sample(33)])
after_sample
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 388        474        678       哈尔滨       一般节点      96      124    呼和浩特
# 962       4448        127        无锡       一般节点      47      425      通辽
# 498         47        314        通辽       一般节点     591      586      绥化
# 444        787         54        玉溪       一般节点     474      422     哈尔滨
# 339        180         18      呼和浩特       一般节点      47      241      通辽
# 812        180         52      呼和浩特       一般节点     474      682     哈尔滨
# 381        474        475       哈尔滨       一般节点    2473      941      吉林
# 5           47        243        通辽       一般节点      96      124    呼和浩特
# 96         474        360       哈尔滨       一般节点    2473      946      吉林
# 164        591       1286        绥化       一般节点   36539     1146      杭州
# 347        180         42      呼和浩特       一般节点    4360      406      南京
# 423        591        558        绥化       一般节点     180       20    呼和浩特
# 367        180        272      呼和浩特       一般节点     474      472     哈尔滨
# 441        591       1300        绥化       一般节点      47      252      通辽
# 157        591       1106        绥化       一般节点   36036      939      长春
# 173        787        307        玉溪       一般节点    4953      686      贵阳
# 74         180         52      呼和浩特       一般节点      63      286      通辽
# 1059        47        252        通辽       一般节点    1997      250      天津
# 88         180        254      呼和浩特       一般节点     235     1663      北京
# 686         63         70        通辽       一般节点    1756     1029      北京
# 600         96        124      呼和浩特       一般节点    1756     1127      北京
# 34          96         99      呼和浩特       一般节点    1257      560      上海
# 358        180        210      呼和浩特       一般节点    1756      642      北京
# 80         180        200      呼和浩特       一般节点    2701      300      大连
# 102        474        467       哈尔滨       一般节点    1257      174      上海
# 306         63        278        通辽       一般节点    3227       70      济南
# 454        787        359        玉溪       一般节点     235     1506      北京
# 38          96        111      呼和浩特       一般节点    3227      468      济南
# 276         47         74        通辽       一般节点    4561     1033      成都
# 488         47        241        通辽       一般节点    3443      503      青岛
# 438        591       1284        绥化       一般节点    2841      237      郑州
# 925       4360        472        南京       一般节点    1997      251      天津
# 420        591        100        绥化       一般节点     235      112      北京
# 391        474       1227       哈尔滨       一般节点    2549      839      沈阳
# 326         96        156      呼和浩特       一般节点    4561     1031      成都
# 50          96        155      呼和浩特       一般节点    1536      681      广州
# 301         63         74        通辽       一般节点    1756      469      北京
# 286         47        259        通辽       一般节点    4561     1087      成都
# 550         63         74        通辽       一般节点    2549     1461      沈阳
# 116        474       1227       哈尔滨       一般节点    2841      341      郑州
# 338        180         10      呼和浩特       一般节点    3213      233      重庆
# 66         180         26      呼和浩特       一般节点   36272      133      太原
# 314         96        114      呼和浩特       一般节点    4561     1086      成都
# 24          63         66        通辽       一般节点     235      112      北京
# 448        787        307        玉溪       一般节点   36422      258      天津
# 552         63        228        通辽       一般节点   36422      324      天津
# 361        180        226      呼和浩特       一般节点    5242      763      西安
# 430        591       1082        绥化       一般节点    1257      560      上海
# 159        591       1250        绥化       一般节点     235     1749      北京
# 409        591         15        绥化       一般节点    2701      181      大连
#
#      to_level      traffic     bandwidth
# 388      一般节点  49289354051  1.000000e+11
# 962      一般节点  50961073987  1.000000e+11
# 498      一般节点  50043006782  1.000000e+11
# 444      一般节点  50571503467  1.000000e+11
# 339      一般节点  51793025548  1.000000e+11
# 812      一般节点  50713290427  1.000000e+11
# 381      一般节点  49402590822  1.000000e+11
# 5        一般节点  49942713747  1.000000e+11
# 96       一般节点  51819320173  1.000000e+11
# 164      一般节点  50089116753  1.000000e+11
# 347      一般节点  50178810628  1.000000e+11
# 423      一般节点  48364223310  1.000000e+11
# 367      一般节点  49398387251  1.000000e+11
# 441      一般节点  50817586398  1.000000e+11
# 157      一般节点  50954337724  1.000000e+11
# 173      一般节点  49399787960  1.000000e+11
# 74       一般节点  49155371449  1.000000e+11
# 1059     网络核心  50358481161  1.000000e+11
# 88       网络核心  51477333650  1.000000e+11
# 686      网络核心  50424129643  1.000000e+11
# 600      网络核心  48884918110  1.000000e+11
# 34       网络核心  49753614568  1.000000e+11
# 358      网络核心  49636949412  1.000000e+11
# 80       网络核心  51884294458  1.000000e+11
# 102      网络核心  49987703744  1.000000e+11
# 306      网络核心  51091741717  1.000000e+11
# 454      网络核心  51542253485  1.000000e+11
# 38       网络核心  48575689938  1.000000e+11
# 276      网络核心  50819524115  1.000000e+11
# 488      网络核心  49653211362  1.000000e+11
# 438      网络核心  49402368215  1.000000e+11
# 925      网络核心  48414179107  1.000000e+11
# 420      网络核心  51157112955  1.000000e+11
# 391      网络核心  51028242209  1.000000e+11
# 326      网络核心  50272713910  1.000000e+11
# 50       网络核心  51538493830  1.000000e+11
# 301      网络核心  49663523668  1.000000e+11
# 286      网络核心  49068568496  1.000000e+11
# 550      网络核心  49909937131  1.000000e+11
# 116      网络核心  48505909225  1.000000e+11
# 338      网络核心  49618057806  1.000000e+11
# 66       网络核心  51023900961  1.000000e+11
# 314      网络核心  49729944227  1.000000e+11
# 24       网络核心  49208537786  1.000000e+11
# 448      网络核心  51727332383  1.000000e+11
# 552      网络核心  49858619385  1.000000e+11
# 361      网络核心  49270522752  1.000000e+11
# 430      网络核心  49355162407  1.000000e+11
# 159      网络核心  49636424242  1.000000e+11
# 409      网络核心  50469487601  1.000000e+11

# %%
systematic_sample=data_before_sample
k=int(len(systematic_sample)/50)
random=5
sample_index=[random-1+i*k for i in range(50)]
systematic_sample_finished=systematic_sample.iloc[sample_index]
systematic_sample_finished
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 4           47        242        通辽       一般节点     474      672     哈尔滨
# 15          47        425        通辽       一般节点    1756     1018      北京
# 26          63         74        通辽       一般节点    2701      181      大连
# 37          96        108      呼和浩特       一般节点    2360      236      太原
# 48          96        141      呼和浩特       一般节点     474      422     哈尔滨
# 59          96        391      呼和浩特       一般节点      47      417      通辽
# 70         180         36      呼和浩特       一般节点    2194      406      唐山
# 81         180        202      呼和浩特       一般节点   36272      247      太原
# 92         180        272      呼和浩特       一般节点    3443      316      青岛
# 107        474        614       哈尔滨       一般节点    3227      724      济南
# 118        474       1238       哈尔滨       一般节点    1756     1008      北京
# 129        474       1410       哈尔滨       一般节点    4069     1205      宁波
# 140        591         56        绥化       一般节点   36036       52      长春
# 151        591        586        绥化       一般节点     180      192    呼和浩特
# 165        591       1290        绥化       一般节点    2194      180      唐山
# 176        787        324        玉溪       一般节点    1536     1941      广州
# 280         47        243        通辽       一般节点    3213      562      重庆
# 292         63          6        通辽       一般节点    2841      418      郑州
# 303         63        228        通辽       一般节点    1536      398      广州
# 314         96        114      呼和浩特       一般节点    4561     1086      成都
# 326         96        156      呼和浩特       一般节点    4561     1031      成都
# 337         96        460      呼和浩特       一般节点    2050      313     石家庄
# 348        180         50      呼和浩特       一般节点      96      460    呼和浩特
# 359        180        214      呼和浩特       一般节点    1257      576      上海
# 370        474        359       哈尔滨       一般节点    1756      594      北京
# 381        474        475       哈尔滨       一般节点    2473      941      吉林
# 392        474       1228       哈尔滨       一般节点      96      134    呼和浩特
# 404        474       1410       哈尔滨       一般节点   36036       54      长春
# 415        591         56        绥化       一般节点   36422      230      天津
# 426        591        586        绥化       一般节点   36422      124      天津
# 437        591       1274        绥化       一般节点    1997      250      天津
# 448        787        307        玉溪       一般节点   36422      258      天津
# 487         47        240        通辽       一般节点     235     1661      北京
# 498         47        314        通辽       一般节点     591      586      绥化
# 537         47        314        通辽       一般节点    1756     1008      北京
# 548         63         66        通辽       一般节点    4069     1205      宁波
# 559         96        102      呼和浩特       一般节点   36036       52      长春
# 587         96        141      呼和浩特       一般节点    3213      246      重庆
# 620        180        264      呼和浩特       一般节点    1129      546      上海
# 667      36539       1140        杭州       一般节点    3227      781      济南
# 717       2473       1043        吉林       一般节点   36422      324      天津
# 759       3757        122        福州       一般节点      96      407    呼和浩特
# 783        591         23        绥化       一般节点     180      218    呼和浩特
# 824         47        252        通辽       一般节点     474     1389     哈尔滨
# 863       4069       1196        宁波       一般节点     591     1290      绥化
# 912         47        242        通辽       一般节点      47      242      通辽
# 953        180        192      呼和浩特       一般节点      47      249      通辽
# 994         63          6        通辽       一般节点    2701      135      大连
# 1039       180        264      呼和浩特       一般节点   36036       54      长春
# 1086     36539       1140        杭州       一般节点     235     1661      北京
#
#      to_level      traffic     bandwidth
# 4        一般节点  50492573662  1.000000e+11
# 15       网络核心  50796899329  1.000000e+11
# 26       网络核心  50364636480  1.000000e+11
# 37       网络核心  48210462086  1.000000e+11
# 48       一般节点  49429192047  1.000000e+11
# 59       一般节点  51570663870  1.000000e+11
# 70       网络核心  50973267302  1.000000e+11
# 81       网络核心  49867223584  1.000000e+11
# 92       网络核心  52854391127  1.000000e+11
# 107      网络核心  51504522549  1.000000e+11
# 118      网络核心  51270474683  1.000000e+11
# 129      一般节点  46523775334  1.000000e+11
# 140      一般节点  48627355195  1.000000e+11
# 151      一般节点  49061517661  1.000000e+11
# 165      网络核心  49758461056  1.000000e+11
# 176      网络核心  48712502205  1.000000e+11
# 280      网络核心  49512830312  1.000000e+11
# 292      网络核心  51392218854  1.000000e+11
# 303      网络核心  50443480874  1.000000e+11
# 314      网络核心  49729944227  1.000000e+11
# 326      网络核心  50272713910  1.000000e+11
# 337      网络核心  50175772267  1.000000e+11
# 348      一般节点  49427879868  1.000000e+11
# 359      网络核心  52204574667  1.000000e+11
# 370      网络核心  49659526739  1.000000e+11
# 381      一般节点  49402590822  1.000000e+11
# 392      一般节点  51278220999  1.000000e+11
# 404      一般节点  49488245045  1.000000e+11
# 415      网络核心  47741796615  1.000000e+11
# 426      网络核心  50282882315  1.000000e+11
# 437      网络核心  50278361522  1.000000e+11
# 448      网络核心  51727332383  1.000000e+11
# 487      网络核心  49873119534  1.000000e+11
# 498      一般节点  50043006782  1.000000e+11
# 537      网络核心  49136293957  1.000000e+11
# 548      一般节点  48141568100  1.000000e+11
# 559      一般节点  49483965391  1.000000e+11
# 587      网络核心  47941844052  1.000000e+11
# 620      网络核心  50207994896  1.000000e+11
# 667      网络核心  49721314562  1.000000e+11
# 717      网络核心  50594312992  1.000000e+11
# 759      一般节点  47597054356  1.000000e+11
# 783      一般节点  50522034278  1.000000e+11
# 824      一般节点  51228405663  1.000000e+11
# 863      一般节点  48726638175  1.000000e+11
# 912      一般节点  49820071586  1.000000e+11
# 953      一般节点  50233070000  1.000000e+11
# 994      网络核心  50680536460  1.000000e+11
# 1039     一般节点  49124032697  1.000000e+11
# 1086     网络核心  51411580502  1.000000e+11

# %%
cluster_stats = data_before_sample.groupby("to_city").size().reset_index(name="cluster_size")#按照to_city分群
avg_cluster_size = cluster_stats["cluster_size"].mean()  # 平均每个城市的数据量
num_clusters_to_sample = int(np.ceil(50 / avg_cluster_size))  # 需抽取的城市数量（向上取整）
sampled_cities = cluster_stats.sample(n=num_clusters_to_sample, random_state=19)["to_city"].tolist()#抽取城市群
cluster_sample_initial = data_before_sample[data_before_sample["to_city"].isin(sampled_cities)]
if len(cluster_sample_initial) > 50:
    cluster_sample_finish = cluster_sample_initial.sample(n=50, random_state=19)#大于50就在这其中随机抽取
else:
    cluster_sample_finish = cluster_sample_initial  # 若不足50则直接保留
cluster_sample_finish = cluster_sample_finish[columns]
cluster_sample_finish
# Out:
#       from_dev  from_port from_city from_level  to_dev  to_port to_city  \
# 17          63          6        通辽       一般节点     591       23      绥化
# 79         180        192      呼和浩特       一般节点     591      586      绥化
# 167        787         51        玉溪       一般节点    4561     1033      成都
# 170        787         60        玉溪       一般节点    4561     1025      成都
# 175        787        317        玉溪       一般节点    5058      118      南宁
# 177        787        325        玉溪       一般节点    4561     1087      成都
# 276         47         74        通辽       一般节点    4561     1033      成都
# 279         47        242        通辽       一般节点    4561     1025      成都
# 284         47        252        通辽       一般节点    5058      118      南宁
# 286         47        259        通辽       一般节点    4561     1087      成都
# 314         96        114      呼和浩特       一般节点    4561     1086      成都
# 326         96        156      呼和浩特       一般节点    4561     1031      成都
# 364        180        256      呼和浩特       一般节点    4561      623      成都
# 377        474        467       哈尔滨       一般节点    5058       70      南宁
# 383        474        670       哈尔滨       一般节点    5058      144      南宁
# 400        474       1374       哈尔滨       一般节点     591       23      绥化
# 498         47        314        通辽       一般节点     591      586      绥化
# 830      36036         54        长春       一般节点     591       11      绥化
# 834        180        264      呼和浩特       一般节点     591       19      绥化
# 836        180         20      呼和浩特       一般节点     591       27      绥化
# 845         47        243        通辽       一般节点     591      526      绥化
# 847         47        252        通辽       一般节点     591      560      绥化
# 850        474        422       哈尔滨       一般节点     591      638      绥化
# 851         47        314        通辽       一般节点     591     1028      绥化
# 861         47        417        通辽       一般节点     591     1284      绥化
# 863       4069       1196        宁波       一般节点     591     1290      绥化
# 1035     36036         54        长春       一般节点     591       23      绥化
# 1097      2473       1460        吉林       一般节点     591      586      绥化
#
#      to_level      traffic     bandwidth
# 17       一般节点  50282047691  1.000000e+11
# 79       一般节点  49504348509  1.000000e+11
# 167      网络核心  51033155364  1.000000e+11
# 170      网络核心  49992676292  1.000000e+11
# 175      一般节点  49579743371  1.000000e+11
# 177      网络核心  48864832885  1.000000e+11
# 276      网络核心  50819524115  1.000000e+11
# 279      网络核心  49436367939  1.000000e+11
# 284      一般节点  49295040137  1.000000e+11
# 286      网络核心  49068568496  1.000000e+11
# 314      网络核心  49729944227  1.000000e+11
# 326      网络核心  50272713910  1.000000e+11
# 364      网络核心  49917991196  1.000000e+11
# 377      一般节点  51745421052  1.000000e+11
# 383      一般节点  50998204735  1.000000e+11
# 400      一般节点  49461593438  1.000000e+11
# 498      一般节点  50043006782  1.000000e+11
# 830      一般节点  49794381448  1.000000e+11
# 834      一般节点  50578150343  1.000000e+11
# 836      一般节点  49701796126  1.000000e+11
# 845      一般节点  48628217146  1.000000e+11
# 847      一般节点  51065218921  1.000000e+11
# 850      一般节点  51214123797  1.000000e+11
# 851      一般节点  50080623466  1.000000e+11
# 861      一般节点  49276967001  1.000000e+11
# 863      一般节点  48726638175  1.000000e+11
# 1035     一般节点  50638071722  1.000000e+11
# 1097     一般节点  48409925693  1.000000e+11
